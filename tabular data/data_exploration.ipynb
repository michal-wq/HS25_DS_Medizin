# %% [markdown]
# # Data Exploration

# %% [markdown]
# Python initialisiern

# %%
import numpy as np
import pandas as pd
from pathlib import Path

# %% [markdown]
# ### Laden der Daten

# %%
df_raw = pd.read_csv('ptbxl_database.csv')
df_raw.head()
# Out:
#    Unnamed: 0  ecg_id  patient_id   age  sex  height  weight  nurse  site  \
# 0           0       1     15709.0  56.0    1     NaN    63.0    2.0   0.0
# 1           1       2     13243.0  19.0    0     NaN    70.0    2.0   0.0
# 2           2       3     20372.0  37.0    1     NaN    69.0    2.0   0.0
# 3           3       4     17014.0  24.0    0     NaN    82.0    2.0   0.0
# 4           4       5     17448.0  19.0    1     NaN    70.0    2.0   0.0
#
#       device  ... validated_by_human  baseline_drift static_noise burst_noise  \
# 0  CS-12   E  ...               True             NaN    , I-V1,           NaN
# 1  CS-12   E  ...               True             NaN          NaN         NaN
# 2  CS-12   E  ...               True             NaN          NaN         NaN
# 3  CS-12   E  ...               True    , II,III,AVF          NaN         NaN
# 4  CS-12   E  ...               True   , III,AVR,AVF          NaN         NaN
#
# ...
